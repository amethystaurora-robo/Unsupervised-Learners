# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
ds1 = pd.read_csv('patients_01.csv')

# %%
num_list = ds1[['age','bmi','alcohol_misuse','health_gen','health_ment','health_phys','dissease']]
plot = sns.scatterplot(x='age',y='bmi', hue='dissease',data=ds1)
